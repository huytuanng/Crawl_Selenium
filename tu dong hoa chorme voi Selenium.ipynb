# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import re
from bs4 import BeautifulSoup
import time
from selenium.webdriver.common.by import By

# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade chromedriver-autoinstaller
# Out:
# ...
#
# ...

# %%
driver =webdriver.Chrome()
url ='https://congbothongtin.ssc.gov.vn/'
driver.get(url)

# %% [markdown]
# click_chon=driver.find_element_by_id('m2263')
# click_chon.click()

# %% [markdown]
# click_chon1=driver.find_element_by_id('m2268')
# click_chon1.click()

# %% [markdown]
# dien_chon=driver.find_element_by_id('txtSearchDsvb')
# dien_chon.send_keys('bồi thường')

# %% [markdown]
# click_chon3=driver.find_element_by_id('btnSearchVB_dsvb')
# click_chon3.click()

# %%
driver.execute_script('window.scrollTo(1,500)')

# %%
els=driver.find_element(By.ID, "pt9:t1:0:c3")

# %%
els=driver.find_element(By.CLASS_NAME, "xgl")
els.text
# Out:
# 'Báo cáo tài chính hợp nhất năm 2022'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 els[1]
#
# TypeError: 'WebElement' object is not subscriptable

# %%
els=driver.find_element("id", "pt9:t1:0:c3")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[386], line 1
# ----> 1 els=driver.find_element("id", "pt9:t1:0:c3")
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# ...

# %%
els=driver.find_element("id", "pt2:LCTT-GT::disAcr")
els.click()

# %%
import pandas as pd

# %%
page_source=BeautifulSoup(driver.page_source)

# %%
target=driver.find_element("id", "pt2:pt1::tabbc")

# %%
df = pd.read_html(driver.page_source)
df
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[387], line 1
# ----> 1 df = pd.read_html(driver.page_source)
#       2 df
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:448, in WebDriver.page_source(self)
#     439 @property
#     440 def page_source(self) -> str:
#     441     """Gets the source of the current page.
#     442
#     443     :Usage:
#    (...)
#     446             driver.page_source
#     447     """
# --> 448     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
# ...

# %%
list=[]

# %%
page=BeautifulSoup(driver.page_source)
page_view=page.find_all('a',class_="xgl")
for i in page_view:
    a=i.get('id')
    list.append(a)

# %%
list
# Out:
# ['pt9:t1:15:cl1',
#  'pt9:t1:16:cl1',
#  'pt9:t1:17:cl1',
#  'pt9:t1:18:cl1',
#  'pt9:t1:19:cl1',
#  'pt9:t1:20:cl1',
#  'pt9:t1:21:cl1',
#  'pt9:t1:22:cl1',
#  'pt9:t1:23:cl1',
#  'pt9:t1:24:cl1',
#  'pt9:t1:25:cl1',
#  'pt9:t1:26:cl1']

# %%
mack = input()
target=driver.find_element("id", "pt9:it8112::content")
target.send_keys(mack)

target=driver.find_element("id", "pt9:id1::content")
target.send_keys("31/12/2016")

target=driver.find_element("id", "pt9:id2::content")
target.send_keys("31/12/2023")



# MỞ THANH CHỌN 
target=driver.find_element("id", "pt9:smc2::drop")
target.click()

#riêng năm
target=els=driver.find_element(By.XPATH, "/html/body/div/form/div[5]/div[2]/div/div/div/table/tbody/tr/td/ul/li[2]/ul/li[3]/label/input")
target.click()
#tổng hợp năm
target=els=driver.find_element(By.XPATH, "/html/body/div/form/div[5]/div[2]/div/div/div/table/tbody/tr/td/ul/li[2]/ul/li[4]/label/input")
target.click()
#mẹ năm
target=els=driver.find_element(By.XPATH, "/html/body/div/form/div[5]/div[2]/div/div/div/table/tbody/tr/td/ul/li[2]/ul/li[8]/label/input")
target.click()
# hợp nhất
target=els=driver.find_element(By.XPATH, "/html/body/div/form/div[5]/div[2]/div/div/div/table/tbody/tr/td/ul/li[2]/ul/li[11]/label/input")
target.click()

target=els=driver.find_element(By.XPATH, "/html/body/div/form/div[3]/div[2]/div/div[1]/div/div[2]/div/div[1]/div/div/div/div/div[1]/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]/span/div[1]/a/span")
target.click()
# Out:
# CTG

# %%
#riêng năm
target=els=driver.find_element(By.XPATH, "/html/body/div/form/div[5]/div[2]/div/div/div/table/tbody/tr/td/ul/li[2]/ul/li[3]/label/input")
target.click()
#tổng hợp năm
target=els=driver.find_element(By.XPATH, "/html/body/div/form/div[5]/div[2]/div/div/div/table/tbody/tr/td/ul/li[2]/ul/li[4]/label/input")
target.click()
#mẹ năm
target=els=driver.find_element(By.XPATH, "/html/body/div/form/div[5]/div[2]/div/div/div/table/tbody/tr/td/ul/li[2]/ul/li[8]/label/input")
target.click()
# hợp nhất
target=els=driver.find_element(By.XPATH, "/html/body/div/form/div[5]/div[2]/div/div/div/table/tbody/tr/td/ul/li[2]/ul/li[11]/label/input")
target.click()

target=els=driver.find_element(By.XPATH, "/html/body/div/form/div[3]/div[2]/div/div[1]/div/div[2]/div/div[1]/div/div/div/div/div[1]/div/table/tbody/tr/td[3]/table/tbody/tr[2]/td[2]/span/div[1]/a/span")
target.click()

# %%
# go back and go forward
driver.back()
driver.forward()

# %%
pt2:KQKD::disAcr
pt2:LCTT-TT::disAcr
pt2:LCTT-GT::disAcr

# %%
df[4]
# Out:
#                                                     0  \
# 0   Chi tiết tin công bốCBTT:Tin Định kỳ Công văn ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                    CBTT:Tin Định kỳ
# 5                                                 NaN
# 6                 Công văn đính chính (file đính kèm)
# 7                                                 NaN
# 8                                     Năm tài chính
# 9                                                 NaN
# 10                                   Ngày ký ban hành
# 11                                                NaN
# 12                                          Trích yếu
# 13                                                NaN
# 14                         Toàn văn báo cáo tài chính
# 15                                                NaN
# ...

# %%
df = pd.read_html(driver.page_source)

# %%
a[-4:]
# Out:
# '2022'

# %%
int(a)
# Out:
# 2022

# %%
"31/12/"+str(int(df[3][1][0][-4:])-1)
# Out:
# '31/12/2021'

# %%
df[16]
# Out:
# Empty DataFrame
# Columns: [Chỉ tiêu, Mã số, Thuyết minh, Lũy kế từ đầu năm đến cuối kỳ này Năm nay, Lũy kế từ đầu năm đến cuối kỳ này Năm trước]
# Index: []

# %%
cf_d=df[17].rename(columns={0: df[2][1][0]+" "+df[3][1][0][:-9],1:'Mã số',
                       2:"Thuyết minh",
                       
                       3:"Lũy kế từ đầu năm đến cuối kỳ này Năm 31/12/"+str(int(df[3][1][0][-4:])),
                       4:"Lũy kế từ đầu năm đến cuối kỳ này Năm 31/12/"+str(int(df[3][1][0][-4:])-1),
                       
                    
                       
                       
                      
                      
                      })

# %%
cf_id=df[17].rename(columns={0: df[2][1][0]+" "+df[3][1][0][:-9],1:'Mã số',
                       2:"Thuyết minh",
                       
                       3:"Lũy kế từ đầu năm đến cuối kỳ này Năm 31/12/"+str(int(df[3][1][0][-4:])),
                       4:"Lũy kế từ đầu năm đến cuối kỳ này Năm 31/12/"+str(int(df[3][1][0][-4:])-1),
                       
                    
                       
                       
                      
                      
                      })

# %%
fs=df[17].rename(columns={0: df[2][1][0]+" "+df[3][1][0][:-9],1:'Mã số',
                       2:"Thuyết minh",
                       3:"Kỳ này Năm 31/12/"+str(int(df[3][1][0][-4:])),
                       4:"Kỳ này Năm 31/12/"+str(int(df[3][1][0][-4:])-1),
                       3:"Lũy kế từ đầu năm đến cuối kỳ này Năm 31/12/"+str(int(df[3][1][0][-4:])),
                       4:"Lũy kế từ đầu năm đến cuối kỳ này Năm 31/12/"+str(int(df[3][1][0][-4:])-1),
                       
                    
                       
                       
                      
                      
                      })

# %%
bs=df[17].rename(columns={0: df[2][1][0]+" "+df[3][1][0][:-9],1:'Mã số',
                       2:"Thuyết minh",
                       3:"31/12/"+str(int(df[3][1][0][-4:])),
                       4:"31/12/"+str(int(df[3][1][0][-4:])-1)
                     
                      
                      
                      })

# %%
df[5]
# Out:
#                                                     0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                    CBTT:Tin Định kỳ
# 4                                                 NaN
# 5                                     Năm tài chính
# 6                                                 NaN
# 7                                    Ngày ký ban hành
# 8                                                 NaN
# 9                                           Trích yếu
# 10                                                NaN
# 11                         Toàn văn báo cáo tài chính
# 12                                                NaN
# 13                              Tổ chức kiểm toán
# 14                                                NaN
# 15                      Lãnh đạo ký báo cáo kiểm toán
# ...

# %%
df[4].loc[24][2]
# Out:
# 'Chưa xác định được khả năng thu hồi giá trị chi phí XD dở dang của công trình Nhà máy thiết bị nâng hạ - Xí nghiệp cơ khí Quang Trung. Đến thời điểm phát hành báo cáo này chúng tôi vẫn chưa xác định được doanh thu còn được Chủ đẩu tư chấp nhận thanh toán và chi phí giá vốn còn phải ghi nhận.Do đó chúng tôi không đủ cơ sở để đánh giá về khả năng thu hồi đối với giá trị chi phí sản xuất kinh doanh dở dang tại ngày 31/12/2022 là: 24.737.248.665 đồng (tại ngày 01/01/2022 là: 24.737.248.665 đồng). Nội dung ý kiến kiểm toán (Không phải nhập với ý kiến Chấp thuận toàn phần)'

# %%
df.loc[21][2]
# Out:
# 'Ý kiến kiểm toánAutocompletes on TAB'

# %%
df[4]
# Out:
#                                                     0  \
# 0   Chi tiết tin công bốCBTT:Tin Định kỳ Năm tài ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                    CBTT:Tin Định kỳ
# 5                                                 NaN
# 6                                     Năm tài chính
# 7                                                 NaN
# 8                                    Ngày ký ban hành
# 9                                                 NaN
# 10                                          Trích yếu
# 11                                                NaN
# 12                         Toàn văn báo cáo tài chính
# 13                                                NaN
# 14                              Tổ chức kiểm toán
# 15                                                NaN
# ...

# %%
df[3][1][0]
# Out:
# 'Báo cáo tài chính hợp nhất năm 2022'

# %%
#tên công ty 
df[2][1][0]
#tên báo cáo 
df[3][1][0]
#Lấy năm báo cáo
int(df[3][1][0][-4:])
# Lấy báo cáo
# Out:
#              0                               1
# 0  Tên công ty  CTCP Vàng bạc đá quý Phú Nhuận

# %%
df[17]
# Out:
#                                          0    1   2             3  \
# 0                                  TÀI SẢN  NaN NaN           NaN
# 1                      A- TÀI SẢN NGẮN HẠN  100 NaN  1.196636e+13
# 2    I. Tiền và các khoản tương đương tiền  110 NaN  8.795481e+11
# 3                                  1. Tiền  111 NaN  8.795481e+11
# 4            2. Các khoản tương đương tiền  112 NaN  0.000000e+00
# ..                                     ...  ...  ..           ...
# 114    13. Lợi ích cổ đông không kiểm soát  429 NaN  0.000000e+00
# 115         II. Nguồn kinh phí và quỹ khác  430 NaN  0.000000e+00
# 116                      1. Nguồn kinh phí  431 NaN  0.000000e+00
# 117   2. Nguồn kinh phí đã hình thành TSCĐ  432 NaN  0.000000e+00
# 118                    TỔNG CỘNG NGUỒN VỐN  440 NaN  1.333712e+13
#
#                 4
# 0             NaN
# 1    9.292192e+12
# 2    3.554548e+11
# 3    3.554548e+11
# 4    0.000000e+00
# ..            ...
# 114  0.000000e+00
# ...

# %%
start_time = time.time()
for a in range(1):
    
    # lay toan bo html
    page_source=BeautifulSoup(driver.page_source)
#lay toan bo td
    vanbanden = page_source.find_all('td')
#lay toan bo vbden_trichyeu
    for i in vanbanden:
        vbd=i.get('id')
        if bool(re.search("vbden_trichyeu_[0-9]{1,7}$",str(vbd))):
            list_vbden.append(vbd)
    driver.execute_script('window.scrollTo(0,250)')
    time.sleep(3.5)
    for i in list_vbden:
        driver.find_element_by_id(i).click()
        time.sleep(1)
        driver.execute_script('window.scrollTo(0,500)')
        time.sleep(1.5)
        #mo bang xu ly
        driver.find_element_by_id('btn_xuly').click()
        #click chon boi thuong
        time.sleep(2)
        driver.find_element_by_id('chk_unit_emp_xem_doisoat-ems').click()
        #tat bang xu ly
        driver.find_element_by_id('btn_action_publish').click()
        time.sleep(1.5)
       
        x=x+1
    list_vbden=[]
    time.sleep(1.5)
    
end_time = time.time()
elapsed_time = end_time - start_time
print(x)
print(elapsed_time)
# Out:
# C:\Users\BOB\AppData\Local\Temp/ipykernel_8912/3161701925.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id(i).click()
# C:\Users\BOB\AppData\Local\Temp/ipykernel_8912/3161701925.py:21: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('btn_xuly').click()
# C:\Users\BOB\AppData\Local\Temp/ipykernel_8912/3161701925.py:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('chk_unit_emp_xem_doisoat-ems').click()
# C:\Users\BOB\AppData\Local\Temp/ipykernel_8912/3161701925.py:26: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('btn_action_publish').click()
# ---------------------------------------------------------------------------
# ...

# %%
start_time = time.time()
for a in range(2,3):
    
    # lay toan bo html
    page_source=BeautifulSoup(driver.page_source)
#lay toan bo td
    vanbanden = page_source.find_all('td')
#lay toan bo vbden_trichyeu
    for i in vanbanden:
        vbd=i.get('id')
        if bool(re.search("vbden_trichyeu_[0-9]{1,7}$",str(vbd))):
            list_vbden.append(vbd)
    driver.execute_script('window.scrollTo(0,250)')
    time.sleep(3.5)
    for i in list_vbden:
        driver.find_element_by_id(i).click()
        time.sleep(2)
        #mo bang xu ly
        driver.find_element_by_id('btn_xuly').click()
        #click chon boi thuong
        time.sleep(2)
        driver.find_element_by_id('chk_unit_emp_xem_doisoat-ems').click()
        #tat bang xu ly
        driver.find_element_by_id('buttonCanThuGonCloseX').click()
        time.sleep(1)
        driver.execute_script('window.scrollTo(0,250)')
        time.sleep(1.6)
        x=x+1
    driver.find_element_by_link_text(str(a)).click()
    driver.execute_script('window.scrollTo(0,400)')
    time.sleep(1)
    list_vbden=[]
end_time = time.time()
elapsed_time = end_time - start_time
print(x)
print(elapsed_time)
# Out:
# 10

# %%
list_vbden=[]

# lay toan bo html
page_source=BeautifulSoup(driver.page_source)
#lay toan bo td
vanbanden = page_source.find_all('td')
#lay toan bo vbden_trichyeu
for i in vanbanden:
    vbd=i.get('id')
    if bool(re.search("vbden_trichyeu_[0-9]{1,7}$",str(vbd))):
            list_vbden.append(vbd)

# %%
so=0
for i in list_vbden:
    so=so+1

# %%
i
# Out:
# 'vbden_trichyeu_2451475'

# %%
driver.execute_script('window.scrollTo(0,280)')

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')

# %%
driver.execute_script('window.scrollTo(0,280)')

# %%
for i in list_vbden:
    click_chon3=driver.find_element_by_id(i)
    click_chon3.click()
# Out:
# C:\Users\BOB\AppData\Local\Temp/ipykernel_21468/1047786041.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   click_chon3=driver.find_element_by_id(i)

# %%
driver.find_element_by_id('btn_xuly').click()
driver.find_element_by_id('chk_unit_emp_xem_doisoat-ems').click()
# Out:
# C:\Users\BOB\AppData\Local\Temp/ipykernel_7912/680452066.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('btn_xuly').click()

# %%
driver.find_element_by_id('chk_unit_emp_xem_doisoat-ems').click()
# Out:
# C:\Users\BOB\AppData\Local\Temp/ipykernel_7912/1235149882.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('chk_unit_emp_xem_doisoat-ems').click()

# %%
click_chon7=driver.find_element_by_id('chk_unit_emp_xem_doisoat-ems')
click_chon7.click()
btn_action_publish

# %%
driver.execute_script('window.scrollTo(0,300)')

# %%
click_chon8=driver.find_element_by_link_text('3')
click_chon8.click()
# Out:
# C:\Users\BOB\AppData\Local\Temp/ipykernel_21468/2733401569.py:1: DeprecationWarning: find_element_by_link_text is deprecated. Please use find_element(by=By.LINK_TEXT, value=link_text) instead
#   click_chon8=driver.find_element_by_link_text('3')

# %%
driver.find_element_by_id('buttonCanThuGonCloseX').click()
# Out:
# C:\Users\BOB\AppData\Local\Temp/ipykernel_7912/80957864.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('buttonCanThuGonCloseX').click()

# %%
//*[@id="vbden_trichyeu_2454588"]

# %%
//*[@id="vbden_trichyeu_2454514"]

# %%
//*[@id="vbden_trichyeu_2435700"]

# %%
page_source=BeautifulSoup(driver.page_source)

# %%
a=[]
for i in page_source:
    vbden=page_source.get('id')
    a.append(vbden)

# %%
import re

# %%
 bool(re.search("vbden_trichyeu_[0-9]{1,7}$", "vbden_trichyeu_22222222"))
# Out:
# False

# %%
vb='a'
if bool(re.search("vbden_trichyeu_[0-9]{1,7}$",vb):
        print(1)
# Out:
#   File "C:\Users\BOB\AppData\Local\Temp/ipykernel_11048/4040885898.py", line 2
#     if bool(re.search("vbden_trichyeu_[0-9]{1,7}$",vb):
#                                                       ^
# SyntaxError: invalid syntax

# %%
for i in new_feed:
    vb=i.get('id')
    if bool(re.search("vbden_trichyeu_[0-9]{1,7}$",str(vb))):
            a.append(vb)

# %%
list_vbden
# Out:
# ['vbden_trichyeu_2454611',
#  'vbden_trichyeu_2454590',
#  'vbden_trichyeu_2454574',
#  'vbden_trichyeu_2454588',
#  'vbden_trichyeu_2454586',
#  'vbden_trichyeu_2454584',
#  'vbden_trichyeu_2454568',
#  'vbden_trichyeu_2454542',
#  'vbden_trichyeu_2454540',
#  'vbden_trichyeu_2454536',
#  'vbden_trichyeu_2454546',
#  'vbden_trichyeu_2454518',
#  'vbden_trichyeu_2454514',
#  'vbden_trichyeu_2454530',
#  'vbden_trichyeu_2454526',
#  'vbden_trichyeu_2454497',
#  'vbden_trichyeu_2454493',
#  'vbden_trichyeu_2454490',
#  'vbden_trichyeu_2454486',
#  'vbden_trichyeu_2454483',
#  'vbden_trichyeu_2454480',
#  'vbden_trichyeu_2454475',
#  'vbden_trichyeu_2454472',
#  'vbden_trichyeu_2454459',
#  'vbden_trichyeu_2454451',
#  'vbden_trichyeu_2454448',
#  'vbden_trichyeu_2454445',
#  'vbden_trichyeu_2454429',
#  'vbden_trichyeu_2454422',
#  'vbden_trichyeu_2454419',
#  'vbden_trichyeu_2454416',
#  'vbden_trichyeu_2454425',
#  'vbden_trichyeu_2454413',
#  'vbden_trichyeu_2454400',
# ...

# %%
for i in vanbanden:
    vbd=i.get('id')
    if bool(re.search("vbden_trichyeu_[0-9]{1,7}$",str(vbd))):
            list_vbden.append(vbd)

# %%
list_vbden=[]
# lay toan bo html
page_source=BeautifulSoup(driver.page_source)
#lay toan bo td
vanbanden = page_source.find_all('td')
#lay toan bo vbden_trichyeu
for i in new_feed:
    vbd=i.get('id')
    if bool(re.search("vbden_trichyeu_[0-9]{1,7}$",str(vb))):
            list_vbden.append(vbd)

# %%
vanbanden = page_source.find_all('td')
vanbanden
# Out:
# [<td class="tr_chk_vanban_class" onclick="onClickCheckBox();" style="text-align:center">
#  <input class="chk_vanban_class" name="chk_vanban" onclick="onClickCheckChonVB(this);" type="checkbox" value="2454611"/>
#  </td>,
#  <td class="danhdau_vanban_hienthi" style="text-align: center; display: none;">
#  <i class="fa fa-star-o fa-lg" data-docid="2454611" data-mark="" onclick="onClickDanhDauVB();" style="color:rgb(206, 205, 205);"></i>
#  </td>,
#  <td class="vanbanden_hienthi1 dsvanban_di_hienthi1" onclick="showDocDetail(2454611,'FALSE', '',this);" style="text-align:center; display: none;">1</td>,
#  <td class="hide_td_sodendi vanbanden_hienthi2" onclick="showDocDetail(2454611,'FALSE', '',this);" style="text-align:center"><span class="" id="div_2454611"></span></td>,
#  <td class="classIofficeNumber" onclick="showDocDetail(2454611,'FALSE', '',this);" style="display: none;"></td>,
# ...

# %%
page_source=BeautifulSoup(driver.page_source)
print(page_source)
# Out:
# <html class="js opacity generatedcontent pointerevents" lang="en-us" style=""><head><meta charset="utf-8"/>
# <!--<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">-->
# <!--<meta sql="begin ? := CLOUD_ADMIN.pk_layout.getMenuHtml('ttds.ems','3972', '0'); end;" name="training" rec-per-page="100" dbms-font="VN8VN3" run="1">-->
# <!--<meta sql="begin ? := CLOUD_ADMIN.pk_dcm_common.sf_get_menu_breadcrumb('ttds.ems','m2268'); end;" name="menu_breadcrumb" rec-per-page="100" dbms-font="VN8VN3" run="1">-->
# <!--<meta sql="begin ? := CLOUD_ADMIN.pk_dcm_common.sf_get_agent_name1('3972'); end;" name="menu_breadcrumb" rec-per-page="100" dbms-font="VN8VN3" run="1">-->
# <title id="title_menu">Văn bản vào sổ</title><link href="login/favicon/favicon_vnpost.ico" id="favicon_eof_page_id" rel="eOffice Icon"/><meta content="" name="description"/>
# <meta content="" name="author"/>
# ...

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# tai file dinh kem va vb lien quan

# %%
driver.find_element_by_xpath('//*[@id="div_file_attach_dsvb"]/div/span').click()
driver.find_element_by_xpath('//*[@id="id_file_vanban_lienquan_vbden"]/div[2]/span').click()
# Out:
# C:\Users\BOB\AppData\Local\Temp/ipykernel_11816/3788095212.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('//*[@id="div_file_attach_dsvb"]/div/span').click()
# C:\Users\BOB\AppData\Local\Temp/ipykernel_11816/3788095212.py:2: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath('//*[@id="id_file_vanban_lienquan_vbden"]/div[2]/span').click()
